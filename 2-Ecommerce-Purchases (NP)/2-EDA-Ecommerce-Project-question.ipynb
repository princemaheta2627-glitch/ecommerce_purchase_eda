# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('ecommercepurchases.csv')
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # 1. Display Top 10 Rows of the Dataset

# %%
data.head(10)

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)

# %% [markdown]
# # 3. Check Datatype of each column

# %%
data.dtypes
data.info()

# %% [markdown]
# # 4. Check null Values in the DataSet

# %%
data.isnull().sum()
data.isnull().values.any()
data.isnull().sum().sum()

# %% [markdown]
# # 5. How many rows & columns are there in Dataset ?

# %%
print("Rows:", data.shape[0])
print("Columns:", data.shape[1])

# %% [markdown]
# # 6. Highest & Lowest Purchase Prices

# %%
print("Highest Purchase Price:", data['Purchase Price'].max())
print("Lowest Purchase Price:", data['Purchase Price'].min())

# %% [markdown]
# # 7. Average Purchase Price

# %%
print("average purchase price",data['Purchase Price'].mean())

# %% [markdown]
# # 8. How Many People Have their French 'fr' as their language ?

# %%
data[data['Language'] == 'fr'].shape[0]

# %% [markdown]
# # 9. Job Titles contains Engineer

# %%
data['Job'].str.contains('Engineer', case=False).sum()

# %% [markdown]
# # 10. Find Email of the person with the following IP address: 132.207.160.22

# %%
data['Job'].str.contains('Engineer', case=False).sum()
data.loc[data['IP Address'] == '132.207.160.22', 'Email'].values[0]

# %% [markdown]
# # 11. How many people have mastercard as their credit card provider & made a purchase above 50 ?

# %%
data[(data['CC Provider'] == 'Mastercard') & (data['Purchase Price'] > 50)]
data[(data['CC Provider'] == 'Mastercard') & (data['Purchase Price'] > 50)].shape[0]

# %% [markdown]
# # 12. Find Email of the person with the following credit card number: 4664825258997302

# %%
data.loc[data['Credit Card'] == 4664825258997302, 'Email'].values[0]

# %% [markdown]
# # 13. How many people purchase during the AM & how many people purchase during the PM ?

# %%
data['AM or PM'].value_counts()

# %% [markdown]
# # 14. How many people have a credit card that expires in 2020 ?

# %%
data[data['CC Exp Date'].str.endswith('20')].shape[0]
